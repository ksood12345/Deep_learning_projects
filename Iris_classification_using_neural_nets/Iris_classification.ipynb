# %% [markdown]
# ## IRIS DATASET CLASSIFICATION USING NEURAL NETWORKS
# In the code below, I have used keras with tensorflow backend to classify iris dataset. User is prompted to enter the following values: </br>
# <ol>
#     <li> Number of neurons in the first hidden layer.</li>
#     <li>Number of neurons in the second hidden layer.</li>
#     <li>Number of epochs for which to train the model.</li>
#     <li>The learning rate value.</li>
#     <li>The batch size.</li>
# </ol>

# %%
# Importing the necessary modules
import warnings
warnings.filterwarnings(action='ignore')
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
class Iris_classification:

    def __init__(self, parameters):
        self.h1 = parameters['n_hidden_units_fc1']
        self.h2 = parameters['n_hidden_units_fc2']
        self.epochs = parameters['n_epochs']
        self.lr = parameters['learning_rate']
        self.bsz = parameters['batch_size']

    def load_and_split_data(self):
        iris_data = load_iris()
        X = iris_data.data
        target = iris_data.target.reshape(-1, 1)
        encoder = OneHotEncoder(sparse=False)
        y = encoder.fit_transform(target)
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 123)
        return (X_train, X_test, y_train, y_test)

    def create_model(self):
        model = Sequential()
        model.add(Dense(self.h1, input_shape = (4,), activation = 'relu', name = 'fc1'))
        model.add(Dense(self.h2, activation = 'relu', name = 'fc2'))
        model.add(Dense(3, activation = 'softmax', name ='output'))
        optimizer = Adam(lr = self.lr)
        model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
        return model

    def train_evaluate(self):
        model = self.create_model()
        X_train, X_test, y_train, y_test = self.load_and_split_data()
        model.fit(X_train, y_train, verbose = 2, batch_size = self.bsz, epochs = self.epochs)
        # Evaluate on test data
        results = model.evaluate(X_test, y_test)
        return results


if __name__ == '__main__':
    parameters = dict()

    # Enter the number of neurons in first and second hidden layers
    parameters['n_hidden_units_fc1'] = int(input('Enter the number of hidden units in first fully connected layer'))
    parameters['n_hidden_units_fc2'] = int(input('Enter the number of hidden units in second fully connected layer'))
    parameters['n_epochs'] = int(input('Enter the number of epochs for training.'))
    parameters['learning_rate'] = float(input('Enter the learning rate.'))
    parameters['batch_size'] = int(input('Enter the batch size.'))

    # Build, train and evaluate the model
    i_classification = Iris_classification(parameters)
    results = i_classification.train_evaluate()
    print('Final test set loss: {:4f}'.format(results[0]))
    print('Final test set accuracy: {:4f}'.format(results[1]))
# Out:
# Enter the number of hidden units in first fully connected layer10
# Enter the number of hidden units in second fully connected layer10
# Enter the number of epochs for training.200
# Enter the learning rate.0.001
# Enter the batch size.10
# Epoch 1/200
#  - 0s - loss: 1.3243 - accuracy: 0.3667
# Epoch 2/200
#  - 0s - loss: 1.2157 - accuracy: 0.3667
# Epoch 3/200
#  - 0s - loss: 1.1487 - accuracy: 0.3667
# Epoch 4/200
#  - 0s - loss: 1.0959 - accuracy: 0.3667
# Epoch 5/200
#  - 0s - loss: 1.0501 - accuracy: 0.3667
# Epoch 6/200
#  - 0s - loss: 1.0185 - accuracy: 0.4583
# Epoch 7/200
#  - 0s - loss: 0.9894 - accuracy: 0.6167
# Epoch 8/200
#  - 0s - loss: 0.9614 - accuracy: 0.6500
# Epoch 9/200
#  - 0s - loss: 0.9333 - accuracy: 0.6500
# Epoch 10/200
#  - 0s - loss: 0.9079 - accuracy: 0.6500
# Epoch 11/200
#  - 0s - loss: 0.8829 - accuracy: 0.6167
# Epoch 12/200
#  - 0s - loss: 0.8563 - accuracy: 0.6417
# Epoch 13/200
#  - 0s - loss: 0.8282 - accuracy: 0.6667
# Epoch 14/200
#  - 0s - loss: 0.8022 - accuracy: 0.6750
# Epoch 15/200
#  - 0s - loss: 0.7749 - accuracy: 0.8083
# Epoch 16/200
#  - 0s - loss: 0.7500 - accuracy: 0.8750
# Epoch 17/200
#  - 0s - loss: 0.7271 - accuracy: 0.9667
# Epoch 18/200
#  - 0s - loss: 0.7040 - accuracy: 0.9667
# Epoch 19/200
#  - 0s - loss: 0.6841 - accuracy: 0.9167
# Epoch 20/200
#  - 0s - loss: 0.6613 - accuracy: 0.9417
# Epoch 21/200
#  - 0s - loss: 0.6371 - accuracy: 0.9667
# Epoch 22/200
#  - 0s - loss: 0.6167 - accuracy: 0.9417
# Epoch 23/200
#  - 0s - loss: 0.5947 - accuracy: 0.9583
# Epoch 24/200
#  - 0s - loss: 0.5744 - accuracy: 0.9667
# Epoch 25/200
#  - 0s - loss: 0.5546 - accuracy: 0.9667
# Epoch 26/200
#  - 0s - loss: 0.5356 - accuracy: 0.9583
# Epoch 27/200
#  - 0s - loss: 0.5168 - accuracy: 0.9583
# Epoch 28/200
#  - 0s - loss: 0.4975 - accuracy: 0.9667
# Epoch 29/200
#  - 0s - loss: 0.4795 - accuracy: 0.9667
# Epoch 30/200
#  - 0s - loss: 0.4619 - accuracy: 0.9667
# Epoch 31/200
#  - 0s - loss: 0.4449 - accuracy: 0.9667
# Epoch 32/200
#  - 0s - loss: 0.4292 - accuracy: 0.9667
# Epoch 33/200
#  - 0s - loss: 0.4131 - accuracy: 0.9667
# Epoch 34/200
#  - 0s - loss: 0.3990 - accuracy: 0.9667
# Epoch 35/200
#  - 0s - loss: 0.3844 - accuracy: 0.9750
# Epoch 36/200
#  - 0s - loss: 0.3703 - accuracy: 0.9667
# Epoch 37/200
#  - 0s - loss: 0.3576 - accuracy: 0.9667
# Epoch 38/200
#  - 0s - loss: 0.3466 - accuracy: 0.9667
# Epoch 39/200
#  - 0s - loss: 0.3334 - accuracy: 0.9750
# Epoch 40/200
#  - 0s - loss: 0.3225 - accuracy: 0.9750
# Epoch 41/200
#  - 0s - loss: 0.3116 - accuracy: 0.9750
# Epoch 42/200
#  - 0s - loss: 0.3011 - accuracy: 0.9750
# Epoch 43/200
#  - 0s - loss: 0.2927 - accuracy: 0.9750
# Epoch 44/200
#  - 0s - loss: 0.2851 - accuracy: 0.9667
# Epoch 45/200
#  - 0s - loss: 0.2753 - accuracy: 0.9750
# Epoch 46/200
#  - 0s - loss: 0.2673 - accuracy: 0.9667
# Epoch 47/200
#  - 0s - loss: 0.2605 - accuracy: 0.9750
# Epoch 48/200
#  - 0s - loss: 0.2489 - accuracy: 0.9750
# Epoch 49/200
#  - 0s - loss: 0.2466 - accuracy: 0.9750
# Epoch 50/200
#  - 0s - loss: 0.2354 - accuracy: 0.9750
# Epoch 51/200
#  - 0s - loss: 0.2316 - accuracy: 0.9667
# Epoch 52/200
#  - 0s - loss: 0.2242 - accuracy: 0.9750
# Epoch 53/200
#  - 0s - loss: 0.2181 - accuracy: 0.9750
# Epoch 54/200
#  - 0s - loss: 0.2131 - accuracy: 0.9750
# Epoch 55/200
#  - 0s - loss: 0.2073 - accuracy: 0.9750
# Epoch 56/200
#  - 0s - loss: 0.2011 - accuracy: 0.9667
# Epoch 57/200
#  - 0s - loss: 0.1951 - accuracy: 0.9750
# Epoch 58/200
#  - 0s - loss: 0.1935 - accuracy: 0.9750
# Epoch 59/200
#  - 0s - loss: 0.1960 - accuracy: 0.9667
# Epoch 60/200
#  - 0s - loss: 0.1826 - accuracy: 0.9750
# Epoch 61/200
#  - 0s - loss: 0.1812 - accuracy: 0.9750
# Epoch 62/200
#  - 0s - loss: 0.1747 - accuracy: 0.9750
# Epoch 63/200
#  - 0s - loss: 0.1707 - accuracy: 0.9833
# Epoch 64/200
#  - 0s - loss: 0.1674 - accuracy: 0.9833
# Epoch 65/200
#  - 0s - loss: 0.1634 - accuracy: 0.9833
# Epoch 66/200
#  - 0s - loss: 0.1614 - accuracy: 0.9750
# Epoch 67/200
#  - 0s - loss: 0.1576 - accuracy: 0.9750
# Epoch 68/200
#  - 0s - loss: 0.1597 - accuracy: 0.9750
# Epoch 69/200
#  - 0s - loss: 0.1522 - accuracy: 0.9750
# Epoch 70/200
#  - 0s - loss: 0.1496 - accuracy: 0.9833
# Epoch 71/200
#  - 0s - loss: 0.1477 - accuracy: 0.9833
# Epoch 72/200
#  - 0s - loss: 0.1436 - accuracy: 0.9833
# Epoch 73/200
#  - 0s - loss: 0.1427 - accuracy: 0.9750
# Epoch 74/200
#  - 0s - loss: 0.1383 - accuracy: 0.9833
# Epoch 75/200
#  - 0s - loss: 0.1371 - accuracy: 0.9833
# Epoch 76/200
#  - 0s - loss: 0.1344 - accuracy: 0.9833
# Epoch 77/200
#  - 0s - loss: 0.1375 - accuracy: 0.9750
# Epoch 78/200
#  - 0s - loss: 0.1350 - accuracy: 0.9750
# Epoch 79/200
#  - 0s - loss: 0.1268 - accuracy: 0.9750
# Epoch 80/200
#  - 0s - loss: 0.1275 - accuracy: 0.9833
# Epoch 81/200
#  - 0s - loss: 0.1254 - accuracy: 0.9833
# Epoch 82/200
#  - 0s - loss: 0.1261 - accuracy: 0.9750
# Epoch 83/200
#  - 0s - loss: 0.1214 - accuracy: 0.9833
# Epoch 84/200
#  - 0s - loss: 0.1216 - accuracy: 0.9750
# Epoch 85/200
#  - 0s - loss: 0.1181 - accuracy: 0.9833
# Epoch 86/200
#  - 0s - loss: 0.1161 - accuracy: 0.9750
# Epoch 87/200
#  - 0s - loss: 0.1197 - accuracy: 0.9750
# Epoch 88/200
#  - 0s - loss: 0.1134 - accuracy: 0.9750
# Epoch 89/200
#  - 0s - loss: 0.1135 - accuracy: 0.9750
# Epoch 90/200
#  - 0s - loss: 0.1141 - accuracy: 0.9833
# Epoch 91/200
#  - 0s - loss: 0.1124 - accuracy: 0.9750
# Epoch 92/200
#  - 0s - loss: 0.1116 - accuracy: 0.9750
# Epoch 93/200
#  - 0s - loss: 0.1083 - accuracy: 0.9833
# Epoch 94/200
#  - 0s - loss: 0.1063 - accuracy: 0.9833
# Epoch 95/200
#  - 0s - loss: 0.1057 - accuracy: 0.9833
# Epoch 96/200
#  - 0s - loss: 0.1034 - accuracy: 0.9833
# Epoch 97/200
#  - 0s - loss: 0.1067 - accuracy: 0.9833
# Epoch 98/200
#  - 0s - loss: 0.1041 - accuracy: 0.9750
# Epoch 99/200
#  - 0s - loss: 0.1003 - accuracy: 0.9833
# Epoch 100/200
#  - 0s - loss: 0.1004 - accuracy: 0.9833
# Epoch 101/200
#  - 0s - loss: 0.1023 - accuracy: 0.9833
# Epoch 102/200
#  - 0s - loss: 0.0997 - accuracy: 0.9750
# Epoch 103/200
#  - 0s - loss: 0.1017 - accuracy: 0.9833
# Epoch 104/200
#  - 0s - loss: 0.0952 - accuracy: 0.9833
# Epoch 105/200
#  - 0s - loss: 0.1031 - accuracy: 0.9750
# Epoch 106/200
#  - 0s - loss: 0.0940 - accuracy: 0.9833
# Epoch 107/200
#  - 0s - loss: 0.0951 - accuracy: 0.9833
# Epoch 108/200
#  - 0s - loss: 0.0945 - accuracy: 0.9833
# Epoch 109/200
#  - 0s - loss: 0.0973 - accuracy: 0.9833
# Epoch 110/200
#  - 0s - loss: 0.0916 - accuracy: 0.9833
# Epoch 111/200
#  - 0s - loss: 0.0929 - accuracy: 0.9833
# Epoch 112/200
#  - 0s - loss: 0.0893 - accuracy: 0.9833
# Epoch 113/200
#  - 0s - loss: 0.0896 - accuracy: 0.9833
# Epoch 114/200
#  - 0s - loss: 0.0895 - accuracy: 0.9833
# Epoch 115/200
#  - 0s - loss: 0.0884 - accuracy: 0.9833
# Epoch 116/200
#  - 0s - loss: 0.0878 - accuracy: 0.9833
# Epoch 117/200
#  - 0s - loss: 0.0885 - accuracy: 0.9833
# Epoch 118/200
#  - 0s - loss: 0.0854 - accuracy: 0.9833
# Epoch 119/200
#  - 0s - loss: 0.0851 - accuracy: 0.9833
# Epoch 120/200
#  - 0s - loss: 0.0843 - accuracy: 0.9833
# Epoch 121/200
#  - 0s - loss: 0.0876 - accuracy: 0.9833
# Epoch 122/200
#  - 0s - loss: 0.0897 - accuracy: 0.9833
# Epoch 123/200
#  - 0s - loss: 0.0821 - accuracy: 0.9833
# Epoch 124/200
#  - 0s - loss: 0.0838 - accuracy: 0.9833
# Epoch 125/200
#  - 0s - loss: 0.0832 - accuracy: 0.9833
# Epoch 126/200
#  - 0s - loss: 0.0807 - accuracy: 0.9833
# Epoch 127/200
#  - 0s - loss: 0.0810 - accuracy: 0.9833
# Epoch 128/200
#  - 0s - loss: 0.0821 - accuracy: 0.9833
# Epoch 129/200
#  - 0s - loss: 0.0860 - accuracy: 0.9833
# Epoch 130/200
#  - 0s - loss: 0.0829 - accuracy: 0.9833
# Epoch 131/200
#  - 0s - loss: 0.0794 - accuracy: 0.9833
# Epoch 132/200
#  - 0s - loss: 0.0801 - accuracy: 0.9833
# Epoch 133/200
#  - 0s - loss: 0.0786 - accuracy: 0.9833
# Epoch 134/200
#  - 0s - loss: 0.0772 - accuracy: 0.9833
# Epoch 135/200
#  - 0s - loss: 0.0812 - accuracy: 0.9833
# Epoch 136/200
#  - 0s - loss: 0.0774 - accuracy: 0.9833
# Epoch 137/200
#  - 0s - loss: 0.0784 - accuracy: 0.9833
# Epoch 138/200
#  - 0s - loss: 0.0759 - accuracy: 0.9833
# Epoch 139/200
#  - 0s - loss: 0.0757 - accuracy: 0.9833
# Epoch 140/200
#  - 0s - loss: 0.0765 - accuracy: 0.9833
# Epoch 141/200
#  - 0s - loss: 0.0753 - accuracy: 0.9833
# Epoch 142/200
#  - 0s - loss: 0.0744 - accuracy: 0.9917
# Epoch 143/200
#  - 0s - loss: 0.0744 - accuracy: 0.9833
# Epoch 144/200
#  - 0s - loss: 0.0746 - accuracy: 0.9833
# Epoch 145/200
#  - 0s - loss: 0.0735 - accuracy: 0.9833
# Epoch 146/200
#  - 0s - loss: 0.0758 - accuracy: 0.9917
# Epoch 147/200
#  - 0s - loss: 0.0744 - accuracy: 0.9833
# Epoch 148/200
#  - 0s - loss: 0.0724 - accuracy: 0.9833
# Epoch 149/200
#  - 0s - loss: 0.0727 - accuracy: 0.9833
# Epoch 150/200
#  - 0s - loss: 0.0722 - accuracy: 0.9833
# Epoch 151/200
#  - 0s - loss: 0.0718 - accuracy: 0.9917
# Epoch 152/200
#  - 0s - loss: 0.0736 - accuracy: 0.9833
# Epoch 153/200
#  - 0s - loss: 0.0705 - accuracy: 0.9833
# Epoch 154/200
#  - 0s - loss: 0.0703 - accuracy: 0.9833
# Epoch 155/200
#  - 0s - loss: 0.0700 - accuracy: 0.9833
# Epoch 156/200
#  - 0s - loss: 0.0715 - accuracy: 0.9833
# Epoch 157/200
#  - 0s - loss: 0.0694 - accuracy: 0.9833
# Epoch 158/200
#  - 0s - loss: 0.0692 - accuracy: 0.9833
# Epoch 159/200
#  - 0s - loss: 0.0769 - accuracy: 0.9750
# Epoch 160/200
#  - 0s - loss: 0.0870 - accuracy: 0.9750
# Epoch 161/200
#  - 0s - loss: 0.0677 - accuracy: 0.9917
# Epoch 162/200
#  - 0s - loss: 0.0714 - accuracy: 0.9833
# Epoch 163/200
#  - 0s - loss: 0.0729 - accuracy: 0.9833
# Epoch 164/200
#  - 0s - loss: 0.0672 - accuracy: 0.9833
# Epoch 165/200
#  - 0s - loss: 0.0753 - accuracy: 0.9750
# Epoch 166/200
#  - 0s - loss: 0.0655 - accuracy: 0.9833
# Epoch 167/200
#  - 0s - loss: 0.0680 - accuracy: 0.9833
# Epoch 168/200
#  - 0s - loss: 0.0678 - accuracy: 0.9833
# Epoch 169/200
#  - 0s - loss: 0.0667 - accuracy: 0.9833
# Epoch 170/200
#  - 0s - loss: 0.0681 - accuracy: 0.9917
# Epoch 171/200
#  - 0s - loss: 0.0661 - accuracy: 0.9833
# Epoch 172/200
#  - 0s - loss: 0.0678 - accuracy: 0.9833
# Epoch 173/200
#  - 0s - loss: 0.0659 - accuracy: 0.9833
# Epoch 174/200
#  - 0s - loss: 0.0695 - accuracy: 0.9833
# Epoch 175/200
#  - 0s - loss: 0.0697 - accuracy: 0.9833
# Epoch 176/200
#  - 0s - loss: 0.0674 - accuracy: 0.9833
# Epoch 177/200
#  - 0s - loss: 0.0674 - accuracy: 0.9917
# Epoch 178/200
#  - 0s - loss: 0.0708 - accuracy: 0.9833
# Epoch 179/200
#  - 0s - loss: 0.0664 - accuracy: 0.9917
# Epoch 180/200
#  - 0s - loss: 0.0640 - accuracy: 0.9917
# Epoch 181/200
#  - 0s - loss: 0.0642 - accuracy: 0.9833
# Epoch 182/200
#  - 0s - loss: 0.0656 - accuracy: 0.9833
# Epoch 183/200
#  - 0s - loss: 0.0656 - accuracy: 0.9833
# Epoch 184/200
#  - 0s - loss: 0.0649 - accuracy: 0.9917
# Epoch 185/200
#  - 0s - loss: 0.0648 - accuracy: 0.9917
# Epoch 186/200
#  - 0s - loss: 0.0622 - accuracy: 0.9833
# Epoch 187/200
#  - 0s - loss: 0.0635 - accuracy: 0.9833
# Epoch 188/200
#  - 0s - loss: 0.0637 - accuracy: 0.9833
# Epoch 189/200
#  - 0s - loss: 0.0624 - accuracy: 0.9917
# Epoch 190/200
#  - 0s - loss: 0.0653 - accuracy: 0.9917
# Epoch 191/200
#  - 0s - loss: 0.0638 - accuracy: 0.9833
# Epoch 192/200
#  - 0s - loss: 0.0656 - accuracy: 0.9833
# Epoch 193/200
#  - 0s - loss: 0.0631 - accuracy: 0.9833
# Epoch 194/200
#  - 0s - loss: 0.0635 - accuracy: 0.9833
# Epoch 195/200
#  - 0s - loss: 0.0615 - accuracy: 0.9917
# Epoch 196/200
#  - 0s - loss: 0.0630 - accuracy: 0.9917
# Epoch 197/200
#  - 0s - loss: 0.0678 - accuracy: 0.9833
# Epoch 198/200
#  - 0s - loss: 0.0612 - accuracy: 0.9833
# Epoch 199/200
#  - 0s - loss: 0.0633 - accuracy: 0.9917
# Epoch 200/200
#  - 0s - loss: 0.0636 - accuracy: 0.9917
# 30/30 [==============================] - 0s 2ms/step
# Final test set loss: 0.101635
# Final test set accuracy: 0.966667
